# %%
import pandas as pd
import os

from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt

# %%
### making an assumption that "target actual is the binary value"

eval_results = {}

datasets = ["bace", "clintox", "deepchem_Lipophilicity", "HIV", "sol_del", "tox21"]

data_map={
    'HIV.csv': {'target':'HIV_active','structure':'smiles'},
    'bace.csv':{'target':'active','structure':'mol'},
    'tox21.csv':{'target':'NR-AhR','structure':'smiles'},
    'clintox.csv':{'target':'CT_TOX','structure':'smiles'},
    'sol_del.csv':{'target':'binned_sol','structure':'smiles'},
    'deepchem_Lipophilicity.csv':{'target':'drug_like','structure':'smiles'}   
}

pred_threshold = 0.5

for file in os.scandir(os.path.join("Complex_Models", "Predictions")):
    target = [data_map[dataset]['target'] for dataset in data_map if dataset[:-4] in file.name][0]
    dataset = [dataset for dataset in data_map if dataset[:-4] in file.name][0]
    df = pd.read_csv(file.path)
    y_actual = df["target_actual"].to_list()
    y_pred = df[target].apply(lambda x: 1 if x > pred_threshold else 0).to_list()

    eval_results[file.name] = {
        "dataset" : dataset,
        "Accuracy_Score": accuracy_score(y_actual, y_pred),
        "F1_Score": f1_score(y_actual, y_pred),
        "ROC_AUC_Score": roc_auc_score(y_actual, y_pred),
        "Log_Loss_Score": log_loss(y_actual, y_pred)
    }
    
df = pd.DataFrame(eval_results).T
df = df.reset_index()
df = df.rename(columns = {"index": "result_file"})
df['split_id'] = df['result_file'].apply(lambda x: "train" if "train" in x else "validate")
df['split_type'] = df['result_file'].apply(lambda x: "custer" if "cluster" in x else "random")
df
# Out:
#                                          result_file  \
# 0                        bace-cluster-train-pred.csv
# 1                     bace-cluster-validate-pred.csv
# 2                         bace-random-train-pred.csv
# 3                      bace-random-validate-pred.csv
# 4                     clintox-cluster-train-pred.csv
# 5                  clintox-cluster-validate-pred.csv
# 6                      clintox-random-train-pred.csv
# 7                   clintox-random-validate-pred.csv
# 8      deepchem_Lipophilicity-cluster-train-pred.csv
# 9   deepchem_Lipophilicity-cluster-validate-pred.csv
# 10      deepchem_Lipophilicity-random-train-pred.csv
# 11   deepchem_Lipophilicity-random-validate-pred.csv
# 12                        HIV-cluster-train-pred.csv
# 13                     HIV-cluster-validate-pred.csv
# 14                         HIV-random-train-pred.csv
# 15                      HIV-random-validate-pred.csv
# 16                    sol_del-cluster-train-pred.csv
# 17                 sol_del-cluster-validate-pred.csv
# 18                     sol_del-random-train-pred.csv
# 19                  sol_del-random-validate-pred.csv
# 20                      tox21-cluster-train-pred.csv
# 21                   tox21-cluster-validate-pred.csv
# 22                       tox21-random-train-pred.csv
# 23                    tox21-random-validate-pred.csv
#
#                        dataset Accuracy_Score  F1_Score ROC_AUC_Score  \
# 0                     bace.csv       0.931624  0.948417      0.919875
# 1                     bace.csv       0.699115  0.802326      0.582665
# 2                     bace.csv       0.987558   0.99073      0.981974
# 3                     bace.csv       0.845815  0.892966      0.791892
# 4                  clintox.csv       0.980907  0.882353      0.924665
# 5                  clintox.csv       0.968326       0.0           0.5
# 6                  clintox.csv       0.984076  0.901961      0.938835
# 7                  clintox.csv       0.932432  0.285714      0.664136
# 8   deepchem_Lipophilicity.csv       0.996359  0.998117      0.954628
# 9   deepchem_Lipophilicity.csv       0.963492  0.981407           0.5
# 10  deepchem_Lipophilicity.csv       0.998039  0.998986      0.971545
# 11  deepchem_Lipophilicity.csv       0.960317  0.979691      0.541343
# 12                     HIV.csv       0.982865  0.692978      0.777729
# 13                     HIV.csv       0.967418  0.377709      0.629915
# 14                     HIV.csv       0.995852  0.938324      0.954139
# 15                     HIV.csv       0.970827  0.502762      0.694375
# 16                 sol_del.csv       0.997914  0.993151       0.99596
# 17                 sol_del.csv       0.846154   0.59375      0.720513
# 18                 sol_del.csv       0.995825  0.987013      0.994869
# 19                 sol_del.csv       0.876471  0.588235      0.719882
# 20                   tox21.csv       0.967307  0.839223      0.877781
# 21                   tox21.csv       0.848269  0.415686      0.648708
# 22                   tox21.csv       0.948437  0.730516      0.796946
# 23                   tox21.csv       0.898271  0.425287      0.645046
#
#    Log_Loss_Score  split_id split_type
# 0        2.361658     train     custer
# 1       10.392336  validate     custer
# 2         0.42973     train     random
# 3         5.32545  validate     random
# 4        0.659457     train     custer
# 5        1.093988  validate     custer
# 6        0.549986     train     random
# 7        2.333737  validate     random
# 8        0.125774     train     custer
# 9        1.260969  validate     custer
# 10       0.067725     train     random
# 11       1.370612  validate     random
# 12       0.591818     train     custer
# 13       1.125356  validate     custer
# 14       0.143266     train     random
# 15        1.00762  validate     random
# 16       0.072032     train     custer
# 17       5.313686  validate     custer
# 18       0.144215     train     random
# 19       4.266574  validate     random
# 20       1.129169     train     custer
# 21       5.240655  validate     custer
# 22       1.780929     train     random
# 23       3.513624  validate     random

# %%
pvt = pd.pivot(df, index = ["dataset", "split_type"], columns = ['split_id'], values = ["Accuracy_Score", "F1_Score", "ROC_AUC_Score", "Log_Loss_Score"])

pvt.columns.names = [None, None]

pvt
# Out:
#                                       Accuracy_Score            F1_Score  \
#                                                train  validate     train
# dataset                    split_type
# HIV.csv                    custer           0.982865  0.967418  0.692978
#                            random           0.995852  0.970827  0.938324
# bace.csv                   custer           0.931624  0.699115  0.948417
#                            random           0.987558  0.845815   0.99073
# clintox.csv                custer           0.980907  0.968326  0.882353
#                            random           0.984076  0.932432  0.901961
# deepchem_Lipophilicity.csv custer           0.996359  0.963492  0.998117
#                            random           0.998039  0.960317  0.998986
# sol_del.csv                custer           0.997914  0.846154  0.993151
#                            random           0.995825  0.876471  0.987013
# tox21.csv                  custer           0.967307  0.848269  0.839223
#                            random           0.948437  0.898271  0.730516
#
#                                                 ROC_AUC_Score            \
#                                        validate         train  validate
# dataset                    split_type
# HIV.csv                    custer      0.377709      0.777729  0.629915
#                            random      0.502762      0.954139  0.694375
# bace.csv                   custer      0.802326      0.919875  0.582665
#                            random      0.892966      0.981974  0.791892
# clintox.csv                custer           0.0      0.924665       0.5
#                            random      0.285714      0.938835  0.664136
# deepchem_Lipophilicity.csv custer      0.981407      0.954628       0.5
#                            random      0.979691      0.971545  0.541343
# sol_del.csv                custer       0.59375       0.99596  0.720513
#                            random      0.588235      0.994869  0.719882
# tox21.csv                  custer      0.415686      0.877781  0.648708
#                            random      0.425287      0.796946  0.645046
#
#                                       Log_Loss_Score
#                                                train   validate
# dataset                    split_type
# HIV.csv                    custer           0.591818   1.125356
#                            random           0.143266    1.00762
# bace.csv                   custer           2.361658  10.392336
#                            random            0.42973    5.32545
# clintox.csv                custer           0.659457   1.093988
#                            random           0.549986   2.333737
# deepchem_Lipophilicity.csv custer           0.125774   1.260969
#                            random           0.067725   1.370612
# sol_del.csv                custer           0.072032   5.313686
#                            random           0.144215   4.266574
# tox21.csv                  custer           1.129169   5.240655
#                            random           1.780929   3.513624

# %%
# need to come back and optimize the visualizations, but thinking something like multiple facets for each score type
# I also need to rotate text to avoid overlap

alt.Chart(df).mark_bar().encode(
    y = "Accuracy_Score:Q",
    x = alt.X("split_id:N", title= None),
    color = "split_id:N",
    column =  alt.Row("dataset:N")
)
# Out:
# alt.Chart(...)
